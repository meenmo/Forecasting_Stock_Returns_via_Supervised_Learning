# %% [markdown]
# ## Advanced Algorithmic Trading DT - V2
#
# ### Updates from Last Version
# - Fix Train/Test to Time Series Train Test Split
# - Train/Validate/Test
# - Do for:
#     - Random Forest
#     - Bagging
#     - Boosting
#     - Linear
#     -

# %% [markdown]
# #### Import Packages

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

import datetime
import gc

from sklearn.ensemble import (BaggingRegressor, RandomForestRegressor, AdaBoostRegressor)
from sklearn.model_selection import ParameterGrid
from sklearn.tree import DecisionTreeRegressor
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import BayesianRidge
from sklearn.metrics import mean_squared_error

from technical_indicators import * # import all function

from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import train_test_split
#import parfit as pf
from sklearn.metrics import r2_score
from sklearn.preprocessing import scale

# %% [markdown]
# #### Set Parameters

# %%
# Set the random seed, number of estimators and the "step factor" used to plot the graph of MSE for each method
random_state = 42  # Seed
n_jobs = -1 # -1 --> all Processors # Parallelisation factor for bagging, random forests (controls the number of processor cores used)
n_estimators = 200 # total number of estimators ot use in the MSE graph
step_factor = 10 # controls cranularity of calculation by stepping through the number of estimators
axis_step = int(n_estimators / step_factor) # 1000/10 = 100 separate calculations will be performed for each of the 3 ensebmle methods

# %% [markdown]
# #### Read in Data via GitHub URL

# %%
url = "https://raw.githubusercontent.com/meenmo/Stat479_Project/master/Data/IBM.csv"
df_ORIGINAL = pd.read_csv(url)

# %% [markdown]
# ***
# ## Clean Data & Create Technical Indicator Variables
#
# - Create Deep copy of dataframe
# - Use Adjusted Close Data
# - Drop Close
# - Rename "Adj. Close" as "Close"
# - Create Lagged Features
# - Drop NaN
# - Create Technical Indicator Variables
# - Drop NaN
# - Re-set index as Date

# %%
df_features = df_ORIGINAL.copy(deep=True) # Create Deep
df_features.drop(['Close'], axis = 1, inplace = True) # drop close column
df_features.columns = ['Date', 'High', 'Low', 'Open', 'Volume', 'Close'] # Close is actually Adj. Close

df_features['Date'] = pd.to_datetime(df_features['Date'])
#df_features.head() # sanity check


"""
Creates Lagged Returns 
- given OHLCV dataframe
- numer of lagged days
"""
def create_lag_features(df, lag_days):
    df_ret = df.copy()
    
    # iterate through the lag days to generate lag values up to lag_days + 1
    for i in range(1,lag_days + 2):
        df_lag = df_ret[['Date', 'Close']].copy()
        # generate dataframe to shift index by i day.
        df_lag['Date'] = df_lag['Date'].shift(-i)
        df_lag.columns = ['Date', 'value_lag' + str(i)]
        # combine the valuelag
        df_ret = pd.merge(df_ret, df_lag, how = 'left', left_on = ['Date'], right_on = ['Date'])
    
    #frees memory
    del df_lag
    
    # calculate today's percentage lag
    df_ret['Today'] = (df_ret['Close'] - df_ret['value_lag1'])/(df_ret['value_lag1']) * 100.0 
    
    # calculate percentage lag
    for i in range(1, lag_days + 1):
        df_ret['lag' + str(i)] = (df_ret['value_lag'+ str(i)] - df_ret['value_lag'+ str(i+1)])/(df_ret['value_lag'+str(i+1)]) * 100.0
    
    # drop unneeded columns which are value_lags
    for i in range(1, lag_days + 2):
        df_ret.drop(['value_lag' + str(i)], axis = 1, inplace = True)
                                                                                                                                                                                                                                                                                                                                     
    return df_ret


### Run Function
df_features = create_lag_features(df_features, 5) # 5 lag features
#df_features.head(7)

# drop earlier data with missing lag features
df_features.dropna(inplace=True)
# reset index
df_features.reset_index(drop = True, inplace = True)


#### GENERATE TECHNICAL INDICATORS FEATURES
df_features = standard_deviation(df_features, 14)

df_features = relative_strength_index(df_features, 14) # periods
df_features = average_directional_movement_index(df_features, 14, 13) # n, n_ADX
df_features = moving_average(df_features, 21) # periods
df_features = exponential_moving_average(df_features, 21) # periods
df_features = momentum(df_features, 14) # 

df_features = average_true_range(df_features, 14)
df_features = bollinger_bands(df_features, 21)
df_features = ppsr(df_features)
df_features = stochastic_oscillator_k(df_features)
df_features = stochastic_oscillator_d(df_features, 14)
df_features = trix(df_features, 14)
df_features = macd(df_features, 26, 12)
df_features = mass_index(df_features)
df_features = vortex_indicator(df_features, 14)

df_features = kst_oscillator(df_features, 10, 10, 10, 15, 10, 15, 20, 30)
df_features = true_strength_index(df_features, 25, 13)

#df_features = accumulation_distribution(df_features, 14) # Causes Problems, apparently
df_features = chaikin_oscillator(df_features)
df_features = money_flow_index(df_features, 14)
df_features = on_balance_volume(df_features, 14)
df_features = force_index(df_features, 14)
df_features = ease_of_movement(df_features, 14)
df_features = commodity_channel_index(df_features, 14)
df_features = keltner_channel(df_features, 14)
df_features = ultimate_oscillator(df_features)
df_features = donchian_channel(df_features, 14)
    
# drop earlier data with missing lag features
df_features.dropna(inplace=True)
df_features = df_features.reset_index(drop = True)



###########################################################################################
# Store Variables now for plots later
daily_index = df_features.index
daily_returns = df_features["Today"]
daily_price   = df_features["Close"]

# Re-set "Date" as the index
df_features = df_features.set_index('Date')

### Sanity Check
df_features.head(10)
# Out:
#                   High         Low        Open    Volume      Close     Today  \
# Date
# 2002-03-14  107.949997  106.589996  107.019997   5335500  74.391068 -0.541176
# 2002-03-15  107.449997  105.589996  106.550003  10864100  74.523666  0.178246
# 2002-03-18  108.639999  106.230003  107.099999   5301200  74.216637 -0.411990
# 2002-03-19  108.050003  106.489998  106.849999   4614800  75.012154  1.071885
# 2002-03-20  106.900001  105.489998  106.900001   4844100  73.623466 -1.851283
# 2002-03-21  106.779999  104.699997  105.699997   5113100  74.516685  1.213226
# 2002-03-22  106.699997  105.070000  106.500000   5507900  73.693192 -1.105114
# 2002-03-25  106.660004  103.500000  105.800003   6277900  72.269615 -1.931761
# 2002-03-26  105.699997  102.300003  103.570000   8144000  71.809052 -0.637285
# 2002-03-27  103.790001  102.500000  103.750000   5602400  72.150978  0.476161
#
#                 lag1      lag2      lag3      lag4     ...         MFI_14  \
# Date                                                   ...
# 2002-03-14 -1.216580  3.097695  0.142742  1.330632     ...       0.714286
# 2002-03-15 -0.541176 -1.216580  3.097695  0.142742     ...       0.642857
# 2002-03-18  0.178246 -0.541176 -1.216580  3.097695     ...       0.714286
# 2002-03-19 -0.411990  0.178246 -0.541176 -1.216580     ...       0.714286
# 2002-03-20  1.071885 -0.411990  0.178246 -0.541176     ...       0.642857
# 2002-03-21 -1.851283  1.071885 -0.411990  0.178246     ...       0.571429
# 2002-03-22  1.213226 -1.851283  1.071885 -0.411990     ...       0.500000
# 2002-03-25 -1.105114  1.213226 -1.851283  1.071885     ...       0.428571
# 2002-03-26 -1.931761 -1.105114  1.213226 -1.851283     ...       0.357143
# 2002-03-27 -0.637285 -1.931761 -1.105114  1.213226     ...       0.357143
#
#                   OBV_14      Force_14        EoM_14    CCI_14  KelChM_14  \
# Date
# 2002-03-14  1.962464e+06 -2.921157e+07  2.286739e-07  0.959960  93.032764
# 2002-03-15  3.445814e+06  5.695471e+06  2.086708e-07  0.713277  93.570735
# 2002-03-18  3.898193e+06 -4.066156e+07  2.500726e-07  0.779588  94.192408
# 2002-03-19  3.372200e+06 -4.964177e+07  2.263920e-07  0.762796  94.770295
# 2002-03-20  2.459121e+06 -1.593928e+07  2.007584e-07  0.060704  95.249347
# 2002-03-21  2.074850e+06 -1.411611e+07  1.220918e-07 -0.248791  95.547059
# 2002-03-22  9.123071e+05  1.101343e+06  3.426329e-08 -0.533297  95.592311
# 2002-03-25  1.004036e+06  1.890940e+06 -5.730833e-09 -1.582313  95.545348
# 2002-03-26 -1.267786e+05 -1.083363e+06 -5.076478e-08 -1.978289  95.397427
# 2002-03-27  1.057100e+06  1.198994e+06 -4.957376e-08 -1.969496  95.286158
#
#             KelChU_14  KelChD_14  Ultimate_Osc  Donchian_14
# Date
# 2002-03-14  95.832764  90.232765      0.034641    13.389999
# 2002-03-15  96.351449  90.790020      0.031385    13.389999
# 2002-03-18  96.916693  91.468123      0.058735    13.389999
# 2002-03-19  97.348152  92.192438      0.057835    13.389999
# 2002-03-20  97.800775  92.697918      0.026201    13.389999
# 2002-03-21  97.918488  93.175630     -0.008129    13.389999
# 2002-03-22  97.837311  93.347311     -0.021320    13.389999
# 2002-03-25  97.848920  93.241776     -0.045311    13.389999
# 2002-03-26  97.776713  93.018141     -0.061006    11.739998
# 2002-03-27  97.453301  93.119015     -0.040421    11.739998
#
# [10 rows x 48 columns]

# %% [markdown]
# ## Create X & y
#
# Drop all data used to create technical indicators (this is done in the book)
#
# NOTE: some technical indicators use Present  data, but ofr simplicity, just ignore this

# %%
### X
list_of_columns_to_exclude = ["High", "Low", "Open", "Volume","Close", "Today"]
X = df_features.copy(deep=True)

X.drop(list_of_columns_to_exclude, axis = 1, inplace = True) # drop close column

### y
y = df_features["Today"]

# Sanity check
# X.head()
# y.head()

# Scale data: 0-1
#X = scale(X)
#y = scale(np.array(y)) # need to convert to numpy array first
# Convert scaled X,Y back to pandas
print(type(X))
print(type(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# #### Split: Train & Validatte / Test
#
# - Train & Validate: < '2018-01-01'
# - Test: >= '2018-01-01'

# %%
# # all training data
X_train_all = X.loc[(X.index < '2018-01-01')]
y_train_all = y[X_train_all.index]

# # creates all test data which is all after January 2018
X_test = X.loc[(X.index >= '2018-01-01'),:]
y_test = y[X_test.index]

# %% [markdown]
# ## Time Series Train Test Split ----

# %% [markdown]
# ### Random Forest

# %%
"""
Execute Random Forest for differnt number of Time Series Splits
- I turned this code into a function to that's it's easy call may times and compare the
        graphs between different split
"""
def Call_Random_Forest(numSplits):
    ### Prepare Random Forest
    ##############################################################################
    # Initialize Random Forest Instance
    rf = RandomForestRegressor(n_estimators=150, n_jobs=-1, random_state=123)

    rf_mse = [] # MSE
    rf_r2 = [] # R2


    ### Time Series Split
    ##############################################################################
    splits = TimeSeriesSplit(n_splits=numSplits) # 3 splits

    splitCount = 0 # dummy count var to track current split num in print statements
    for train_index, test_index in splits.split(X_train_all):
        splitCount += 1 

        # Train Split
        X_train = X_train_all.iloc[0:len(train_index) - 1,:].copy(deep=True)
        y_train = y[X_train.index]

        # Validate Split
        X_val = X_train_all.iloc[len(train_index) - 1:,:].copy(deep=True)
        y_val = y[X_val.index]

        # Print Statements
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
        print("Split: ", splitCount)
        print('Observations: ', (X_train.shape[0] + X_test.shape[0]))
        #print('Cutoff date, or first date in validation data: ', X_val.iloc[0,0])
        print('Training Observations: ', (X_train.shape[0]))
        print('Testing Observations: ', (X_test.shape[0]))
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")

        ### Run Random Forest
        rf.fit(X_train, y_train)
        prediction = rf.predict(X_val)

        mse = mean_squared_error(y_val, prediction)
        r2  = r2_score(y_val, prediction)

        rf_mse.append(mse)
        rf_r2.append(r2)

    # print("rf_mse: ", rf_mse)
    # print("rf_r2: ", rf_r2)



    ### Time Series Split
    ##############################################################################
    # Plot the chart of MSE versus number of estimators
    plt.figure(figsize=(12, 7))
    plt.title('Random Forest - MSE & R-Squared')

    ### MSE
    plt.plot(list(range(1,splitCount+1)), rf_mse, 'b-', color="blue", label='MSE')
    plt.plot(list(range(1,splitCount+1)), rf_r2, 'b-', color="green", label='R-Squared')
    plt.plot(list(range(1,splitCount+1)), np.array([0] * splitCount), 'b-', color="red", label='Zero')


    plt.legend(loc='upper right')
    plt.xlabel('Train/Test Split Number')
    plt.ylabel('Mean Squared Error & R-Squared')
    plt.show()

# %% [markdown]
# ### Bagging

# %%
"""
Execute Bagging for differnt number of Time Series Splits
- I turned this code into a function to that's it's easy call may times and compare the
        graphs between different split
"""
def Call_Bagging(numSplits):
    ### Prepare Bagging
    ##############################################################################
    # Initialize Bagging Instance
    bagging = BaggingRegressor(n_estimators=150, n_jobs=-1, random_state=123)

    bagging_mse = [] # MSE
    bagging_r2 = [] # R2


    ### Time Series Split
    ##############################################################################
    splits = TimeSeriesSplit(n_splits=numSplits) # 3 splits

    splitCount = 0 # dummy count var to track current split num in print statements
    for train_index, test_index in splits.split(X_train_all):
        splitCount += 1 

        # Train Split
        X_train = X_train_all.iloc[0:len(train_index) - 1,:].copy(deep=True)
        y_train = y[X_train.index]

        # Validate Split
        X_val = X_train_all.iloc[len(train_index) - 1:,:].copy(deep=True)
        y_val = y[X_val.index]

#         # Print Statements
#         print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
#         print("Split: ", splitCount)
#         print('Observations: ', (X_train.shape[0] + X_test.shape[0]))
#         #print('Cutoff date, or first date in validation data: ', X_val.iloc[0,0])
#         print('Training Observations: ', (X_train.shape[0]))
#         print('Testing Observations: ', (X_test.shape[0]))
#         print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")

        ### Run Random Forest
        bagging.fit(X_train, y_train)
        prediction = bagging.predict(X_val)

        mse = mean_squared_error(y_val, prediction)
        r2  = r2_score(y_val, prediction)

        bagging_mse.append(mse)
        bagging_r2.append(r2)


    ### Time Series Split
    ##############################################################################
    # Plot the chart of MSE versus number of estimators
    plt.figure(figsize=(12, 7))
    plt.title('Bagging - MSE & R-Squared')

    ### MSE
    plt.plot(list(range(1,splitCount+1)), bagging_mse, 'b-', color="blue", label='MSE')
    plt.plot(list(range(1,splitCount+1)), bagging_r2, 'b-', color="green", label='R-Squared')
    plt.plot(list(range(1,splitCount+1)), np.array([0] * splitCount), 'b-', color="red", label='Zero')


    plt.legend(loc='upper right')
    plt.xlabel('Train/Test Split Number')
    plt.ylabel('Mean Squared Error & R-Squared')
    plt.show()

# %% [markdown]
# ### Boosting

# %%
"""
Execute Random Forest for differnt number of Time Series Splits
- I turned this code into a function to that's it's easy call may times and compare the
        graphs between different split
"""
def Call_Boosting(numSplits):
    ### Prepare Boosting
    ##############################################################################
    # Initialize Boosting Instance    
    boosting = AdaBoostRegressor(DecisionTreeRegressor(),
                                 n_estimators=150, random_state=123,learning_rate=0.01)

    boosting_mse = [] # MSE
    boosting_r2 = [] # R2


    ### Time Series Split
    ##############################################################################
    splits = TimeSeriesSplit(n_splits=numSplits) # 3 splits

    splitCount = 0 # dummy count var to track current split num in print statements
    for train_index, test_index in splits.split(X_train_all):
        splitCount += 1 

        # Train Split
        X_train = X_train_all.iloc[0:len(train_index) - 1,:].copy(deep=True)
        y_train = y[X_train.index]

        # Validate Split
        X_val = X_train_all.iloc[len(train_index) - 1:,:].copy(deep=True)
        y_val = y[X_val.index]

#         # Print Statements
#         print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
#         print("Split: ", splitCount)
#         print('Observations: ', (X_train.shape[0] + X_test.shape[0]))
#         #print('Cutoff date, or first date in validation data: ', X_val.iloc[0,0])
#         print('Training Observations: ', (X_train.shape[0]))
#         print('Testing Observations: ', (X_test.shape[0]))
#         print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")

        ### Run Random Forest
        boosting.fit(X_train, y_train)
        prediction = boosting.predict(X_val)

        mse = mean_squared_error(y_val, prediction)
        r2  = r2_score(y_val, prediction)

        boosting_mse.append(mse)
        boosting_r2.append(r2)


    ### Time Series Split
    ##############################################################################
    # Plot the chart of MSE versus number of estimators
    plt.figure(figsize=(12, 7))
    plt.title('Boosting - MSE & R-Squared')

    ### MSE
    plt.plot(list(range(1,splitCount+1)), boosting_mse, 'b-', color="blue", label='MSE')
    plt.plot(list(range(1,splitCount+1)), boosting_r2, 'b-', color="green", label='R-Squared')
    plt.plot(list(range(1,splitCount+1)), np.array([0] * splitCount), 'b-', color="red", label='Zero')


    plt.legend(loc='upper right')
    plt.xlabel('Train/Test Split Number')
    plt.ylabel('Mean Squared Error & R-Squared')
    plt.show()

# %% [markdown]
# ### Linear Regression

# %%
"""
Execute Linear Regression for different number of Time Series Splits
"""
def Call_Linear(numSplits):
    ### Prepare Random Forest
    ##############################################################################
    # Initialize Random Forest Instance
    linear = LinearRegression(n_jobs=-1, normalize=True, fit_intercept=False) # if we don't fit the intercept we get a better prediction

    linear_mse = [] # MSE
    linear_r2 = [] # R2


    ### Time Series Split
    ##############################################################################
    splits = TimeSeriesSplit(n_splits=numSplits) # 3 splits

    splitCount = 0 # dummy count var to track current split num in print statements
    for train_index, test_index in splits.split(X_train_all):
        splitCount += 1 
        
        # Train Split
        X_train = X_train_all.iloc[train_index,:]
        y_train = y[X_train.index]

        # Validate Split
        X_val = X_train_all.iloc[test_index,:]
        y_val = y[X_val.index]


        linear.fit(X_train, y_train)
        prediction = linear.predict(X_val)

        mse = mean_squared_error(y_val, prediction)
        r2  = r2_score(y_val, prediction)


        linear_mse.append(mse)
        linear_r2.append(r2)
        
        


    ### Time Series Split
    ##############################################################################
    # Plot the chart of MSE versus number of estimators
    plt.figure(figsize=(12, 7))
    plt.title('Linear Regression - MSE & R-Squared')

    ### MSE
    plt.plot(list(range(1,splitCount+1)), linear_mse, 'b-', color="blue", label='MSE')
    plt.plot(list(range(1,splitCount+1)), linear_r2, 'b-', color="green", label='R-Squared')
    plt.plot(list(range(1,splitCount+1)), np.array([0] * splitCount), 'b-', color="red", label='Zero')


    plt.legend(loc='upper right')
    plt.xlabel('Train/Test Split Number')
    plt.ylabel('Mean Squared Error & R-Squared')
    plt.show()
    
    print(np.mean(linear_mse))

# %% [markdown]
# ### Bayesian Ridge

# %%
"""
Execute Bayesian Ridge for different number of Time Series Splits
"""
def Call_BayesianRidge(numSplits):
    ### Prepare Random Forest
    ##############################################################################
    # Initialize Random Forest Instance
    bayesian_ridge = BayesianRidge(normalize=True)

    bayesian_ridge_mse = [] # MSE
    bayesian_ridge_r2 = [] # R2


    ### Time Series Split
    ##############################################################################
    splits = TimeSeriesSplit(n_splits=numSplits) # 3 splits

    splitCount = 0 # dummy count var to track current split num in print statements
    for train_index, test_index in splits.split(X_train_all):
        splitCount += 1 

        # Train Split
        X_train = X_train_all.iloc[0:len(train_index) - 1,:].copy(deep=True)
        y_train = y[X_train.index]

        # Validate Split
        X_val = X_train_all.iloc[len(train_index) - 1:,:].copy(deep=True)
        y_val = y[X_val.index]

#         # Print Statements
#         print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
#         print("Split: ", splitCount)
#         print('Observations: ', (X_train.shape[0] + X_test.shape[0]))
#         #print('Cutoff date, or first date in validation data: ', X_val.iloc[0,0])
#         print('Training Observations: ', (X_train.shape[0]))
#         print('Testing Observations: ', (X_test.shape[0]))
#         print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")

        ### Run Random Forest
        bayesian_ridge.fit(X_train, y_train)
        prediction = bayesian_ridge.predict(X_val)

        mse = mean_squared_error(y_val, prediction)
        r2  = r2_score(y_val, prediction)

        bayesian_ridge_mse.append(mse)
        bayesian_ridge_r2.append(r2)


    ### Time Series Split
    ##############################################################################
    # Plot the chart of MSE versus number of estimators
    plt.figure(figsize=(12, 7))
    plt.title('Bayesian Ridge Regression - MSE & R-Squared')

    ### MSE
    plt.plot(list(range(1,splitCount+1)), bayesian_ridge_mse, 'b-', color="blue", label='MSE')
    plt.plot(list(range(1,splitCount+1)), bayesian_ridge_r2, 'b-', color="green", label='R-Squared')
    plt.plot(list(range(1,splitCount+1)), np.array([0] * splitCount), 'b-', color="red", label='Zero')


    plt.legend(loc='upper right')
    plt.xlabel('Train/Test Split Number')
    plt.ylabel('Mean Squared Error & R-Squared')
    plt.show()

# %% [markdown]
# #### NOTE: For Random Forests, 150 Estimators seems optimal.
#
# - The optimal number of estimators for random forests & bagging is actually arround 400 but this seems a little too large, since we're not running supercomputers. So for computaional purposes 150 surves us better.
# - Using Adjusted Close prices --> decreases our MSE & increases our R2
# - Using more features than just Lagged returns --> decreases our MSE & increases our R2
#
#
# ##### Random Forest
# - Optimal: __150 Estimators__
#
# ##### Bagging
# - Optimal: __150 Estimators__
#
# ##### Boosting
# - Optimal: __150 Estimators__
# - Note the when only Lag features are used, the optimal number of estimators is around 50 and is in a U shape, but when more features are included out MSE become monotone decreasing

# %% [markdown]
# #### Misc. Graphs

# %%
# figure dimenstions
length = 15
height = 5

### Prices
plt.figure(figsize=(length, height))
plt.title('IBM Adj Close Price Graph')
plt.plot(daily_index, daily_price, 'b-', color="blue", label='Prices')
plt.legend(loc='upper right')
plt.xlabel('Days')
plt.ylabel('Prices')
plt.show()

### Returns
plt.figure(figsize=(length, height))
plt.title('IBM Daily Returns')
plt.plot(daily_index, daily_returns, 'b-', color="blue", label='Returns')
plt.legend(loc='upper right')
plt.xlabel('Days')
plt.ylabel('Returns')
plt.show()

### Cumulative Returns
plt.figure(figsize=(length, height))
plt.title('IBM Cumulative Returns')
cumulative_returns = daily_returns.cumsum()
plt.plot(daily_index, cumulative_returns, 'b-', color="green", label='Cumulative Returns')
plt.legend(loc='upper right')
plt.xlabel('Days')
plt.ylabel('Cumulative Return')
plt.show()

# %%
Call_Random_Forest(20) 
# Call_Bagging(20) 
# Call_Boosting(20) # takes forever to run
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  1
# Observations:  409
# Training Observations:  198
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  2
# Observations:  598
# Training Observations:  387
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  3
# Observations:  787
# Training Observations:  576
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  4
# Observations:  976
# Training Observations:  765
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  5
# Observations:  1165
# Training Observations:  954
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  6
# Observations:  1354
# Training Observations:  1143
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  7
# Observations:  1543
# Training Observations:  1332
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  8
# Observations:  1732
# Training Observations:  1521
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  9
# Observations:  1921
# Training Observations:  1710
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  10
# Observations:  2110
# Training Observations:  1899
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  11
# Observations:  2299
# Training Observations:  2088
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  12
# Observations:  2488
# Training Observations:  2277
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  13
# Observations:  2677
# Training Observations:  2466
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  14
# Observations:  2866
# Training Observations:  2655
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  15
# Observations:  3055
# Training Observations:  2844
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  16
# Observations:  3244
# Training Observations:  3033
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  17
# Observations:  3433
# Training Observations:  3222
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  18
# Observations:  3622
# Training Observations:  3411
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  19
# Observations:  3811
# Training Observations:  3600
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  20
# Observations:  4000
# Training Observations:  3789
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
Call_Random_Forest(100) # see how it performs for a very large number of splits
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  1
# Observations:  289
# Training Observations:  78
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  2
# Observations:  328
# Training Observations:  117
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  3
# Observations:  367
# Training Observations:  156
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  4
# Observations:  406
# Training Observations:  195
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  5
# Observations:  445
# Training Observations:  234
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  6
# Observations:  484
# Training Observations:  273
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  7
# Observations:  523
# Training Observations:  312
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  8
# Observations:  562
# Training Observations:  351
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  9
# Observations:  601
# Training Observations:  390
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  10
# Observations:  640
# Training Observations:  429
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  11
# Observations:  679
# Training Observations:  468
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  12
# Observations:  718
# Training Observations:  507
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  13
# Observations:  757
# Training Observations:  546
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  14
# Observations:  796
# Training Observations:  585
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  15
# Observations:  835
# Training Observations:  624
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  16
# Observations:  874
# Training Observations:  663
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  17
# Observations:  913
# Training Observations:  702
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  18
# Observations:  952
# Training Observations:  741
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  19
# Observations:  991
# Training Observations:  780
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  20
# Observations:  1030
# Training Observations:  819
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  21
# Observations:  1069
# Training Observations:  858
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  22
# Observations:  1108
# Training Observations:  897
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  23
# Observations:  1147
# Training Observations:  936
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  24
# Observations:  1186
# Training Observations:  975
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  25
# Observations:  1225
# Training Observations:  1014
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  26
# Observations:  1264
# Training Observations:  1053
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  27
# Observations:  1303
# Training Observations:  1092
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  28
# Observations:  1342
# Training Observations:  1131
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  29
# Observations:  1381
# Training Observations:  1170
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  30
# Observations:  1420
# Training Observations:  1209
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  31
# Observations:  1459
# Training Observations:  1248
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  32
# Observations:  1498
# Training Observations:  1287
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  33
# Observations:  1537
# Training Observations:  1326
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  34
# Observations:  1576
# Training Observations:  1365
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  35
# Observations:  1615
# Training Observations:  1404
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  36
# Observations:  1654
# Training Observations:  1443
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  37
# Observations:  1693
# Training Observations:  1482
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  38
# Observations:  1732
# Training Observations:  1521
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  39
# Observations:  1771
# Training Observations:  1560
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  40
# Observations:  1810
# Training Observations:  1599
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  41
# Observations:  1849
# Training Observations:  1638
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  42
# Observations:  1888
# Training Observations:  1677
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  43
# Observations:  1927
# Training Observations:  1716
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  44
# Observations:  1966
# Training Observations:  1755
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  45
# Observations:  2005
# Training Observations:  1794
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  46
# Observations:  2044
# Training Observations:  1833
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  47
# Observations:  2083
# Training Observations:  1872
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  48
# Observations:  2122
# Training Observations:  1911
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  49
# Observations:  2161
# Training Observations:  1950
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  50
# Observations:  2200
# Training Observations:  1989
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  51
# Observations:  2239
# Training Observations:  2028
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  52
# Observations:  2278
# Training Observations:  2067
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  53
# Observations:  2317
# Training Observations:  2106
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  54
# Observations:  2356
# Training Observations:  2145
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  55
# Observations:  2395
# Training Observations:  2184
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  56
# Observations:  2434
# Training Observations:  2223
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  57
# Observations:  2473
# Training Observations:  2262
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  58
# Observations:  2512
# Training Observations:  2301
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  59
# Observations:  2551
# Training Observations:  2340
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  60
# Observations:  2590
# Training Observations:  2379
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  61
# Observations:  2629
# Training Observations:  2418
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  62
# Observations:  2668
# Training Observations:  2457
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  63
# Observations:  2707
# Training Observations:  2496
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  64
# Observations:  2746
# Training Observations:  2535
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  65
# Observations:  2785
# Training Observations:  2574
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  66
# Observations:  2824
# Training Observations:  2613
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  67
# Observations:  2863
# Training Observations:  2652
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  68
# Observations:  2902
# Training Observations:  2691
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  69
# Observations:  2941
# Training Observations:  2730
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  70
# Observations:  2980
# Training Observations:  2769
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  71
# Observations:  3019
# Training Observations:  2808
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  72
# Observations:  3058
# Training Observations:  2847
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  73
# Observations:  3097
# Training Observations:  2886
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  74
# Observations:  3136
# Training Observations:  2925
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  75
# Observations:  3175
# Training Observations:  2964
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  76
# Observations:  3214
# Training Observations:  3003
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  77
# Observations:  3253
# Training Observations:  3042
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  78
# Observations:  3292
# Training Observations:  3081
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  79
# Observations:  3331
# Training Observations:  3120
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  80
# Observations:  3370
# Training Observations:  3159
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  81
# Observations:  3409
# Training Observations:  3198
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  82
# Observations:  3448
# Training Observations:  3237
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  83
# Observations:  3487
# Training Observations:  3276
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  84
# Observations:  3526
# Training Observations:  3315
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  85
# Observations:  3565
# Training Observations:  3354
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  86
# Observations:  3604
# Training Observations:  3393
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  87
# Observations:  3643
# Training Observations:  3432
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  88
# Observations:  3682
# Training Observations:  3471
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  89
# Observations:  3721
# Training Observations:  3510
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  90
# Observations:  3760
# Training Observations:  3549
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  91
# Observations:  3799
# Training Observations:  3588
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  92
# Observations:  3838
# Training Observations:  3627
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  93
# Observations:  3877
# Training Observations:  3666
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  94
# Observations:  3916
# Training Observations:  3705
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  95
# Observations:  3955
# Training Observations:  3744
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  96
# Observations:  3994
# Training Observations:  3783
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  97
# Observations:  4033
# Training Observations:  3822
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  98
# Observations:  4072
# Training Observations:  3861
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  99
# Observations:  4111
# Training Observations:  3900
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Split:  100
# Observations:  4150
# Training Observations:  3939
# Testing Observations:  211
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
Call_Linear(100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-217-93620de74575> in <module>
# ----> 1 Call_Linear(100)
#
# <ipython-input-216-f1aa7288332a> in Call_Linear(numSplits)
#      59     plt.show()
#      60
# ---> 61     print(mean(linear_mse))
#
# NameError: name 'mean' is not defined

# %%
Call_BayesianRidge(100)
